# %% [markdown]
# - push X: 정수 X를 큐에 넣는 연산이다.
# - pop: 큐에서 가장 앞에 있는 정수를 빼고, 그 수를 출력한다. 만약 큐에 들어있는 정수가 없는 경우에는 -1을 출력한다.
# - size: 큐에 들어있는 정수의 개수를 출력한다.
# - empty: 큐가 비어있으면 1, 아니면 0을 출력한다.
# - front: 큐의 가장 앞에 있는 정수를 출력한다. 만약 큐에 들어있는 정수가 없는 경우에는 -1을 출력한다.
# - back: 큐의 가장 뒤에 있는 정수를 출력한다. 만약 큐에 들어있는 정수가 없는 경우에는 -1을 출력한다.

# %%
# 시간 초과

def push(x) :
    q.append(x)
    return 


def pop() :
    if q :
        return q.pop(0)
    return -1
    

def size() :
    return len(q)


def empty() :
    if q :
        return 0
    return 1

def front() :
    if q :
        return q[0]
    return -1

def back() :
    if q :
        return q[-1]
    return -1


N = int(input())
q = []
for _ in range(N) :
    command = input().split()


    if len(command) > 1 :
        push(int(command[-1]))

    else :
        ans = globals()[command[0]]()
        print(ans)

    # globals() : 현재 전역 네임스페이스를 딕셔너리로 반환해주는 것
    # 함수 이름이 문자열로 되어있을 때, globals()를 활용해 함수 호출 가능
    #globals()를 사용하지 않으려면 딕셔너리를 이용해 명령어와 함수를 매핑해야 함
    '''
    commands = {
        'pop': pop,
        'size': size,
        'empty': empty,
        'front': front,
        'back': back
    }
    '''

# %%
def push(x) :
    q.append(x)
    return 


def pop() :
    if q :
        return q.pop(0)
    return -1
    

def size() :
    return len(q)


def empty() :
    if q :
        return 0
    return 1

def front() :
    if q :
        return q[0]
    return -1

def back() :
    if q :
        return q[-1]
    return -1


N = int(input())
q = []
for _ in range(N) :
    command = input().split()
    commands = {
        'pop': pop,
        'size': size,
        'empty': empty,
        'front': front,
        'back': back
    }

    if len(command) > 1 :
        push(int(command[-1]))

    else :
        ans = commands[command[0]]()
        print(ans)

# %%
# 시간초과나서 조건문으로 변경
# 하지만 시간초과

import sys
sys.stdin = open('백준/test.txt')


N = int(input())
q = []
ans = 0

for _ in range(N) :
    command = input().split()

    if len(command) > 1 :
        x = int(command[1])
        q.append(x)
        
    else :
        if command[0] == 'pop' :
            if q :
                ans = q.pop(0)
            else :
                ans = -1

        elif command[0] == 'size' :
            ans = len(q)

        elif command[0] == 'empty' :
            if q :
                ans = 0
            else :
                ans = 1
        
        elif command[0] == 'front' :
            if q :
                ans = q[0]
            else :
                ans = -1

        
        elif command[0] == 'back' :
            if q :
                ans = q[-1]
            else :
                ans = -1

        print(ans)

# %%
# deque, sys.stdin.readline 사용
# python3 : 112534Kb, 1700ms
# pypy : 162137KB, 684ms

import sys
input = sys.stdin.readline

from collections import deque

N = int(input())
q = deque()
ans = 0

for _ in range(N) :
    command = input().split()

    if len(command) > 1 :
        x = int(command[1])
        q.append(x)
        
    else :
        if command[0] == 'pop' :
            if q :
                ans = q.popleft()
            else :
                ans = -1

        elif command[0] == 'size' :
            ans = len(q)

        elif command[0] == 'empty' :
            if q :
                ans = 0
            else :
                ans = 1
        
        elif command[0] == 'front' :
            if q :
                ans = q[0]
            else :
                ans = -1

        
        elif command[0] == 'back' :
            if q :
                ans = q[-1]
            else :
                ans = -1

        print(ans)
